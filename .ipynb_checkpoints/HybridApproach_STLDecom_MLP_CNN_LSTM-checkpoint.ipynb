# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
import time
from pandas.plotting import lag_plot
from pandas.plotting import autocorrelation_plot
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error 
from math import sqrt
from numpy import hstack
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
import warnings 
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from keras import metrics
from stldecompose import decompose, forecast
from stldecompose.forecast_funcs import (naive,
                                         drift, 
                                         mean, 
                                         seasonal_naive)

#data = pd.read_csv('/Users/alket/Desktop/dati/new_data_backfill_forwfill.csv',index_col = 0)
data = pd.read_csv('/Users/alket/Desktop/dati/new_data_Modena_backfill_forwfill.csv',index_col = 0)
# preparazione dati per due celle
agg_by_cell = data.groupby(by = ['cell_num'])

# %%
trend_data = []
residual_data = []
seasonal_data = []

for i, k in agg_by_cell:
    
    dates4dec = []
    cell_values = []
    k = k.iloc[::4,:]
    print(len(k))
    for index, row in k.iterrows():
        
        date = row['date']
        h = str(row['hours'])
   
        h = h.split('.')
    
        if len(h[0])<2:
            h = h[1]+h[0]
        else: 
            h = h[0]
   
        minutes = str(row['minutes'])
        m = ''
        minutes = minutes.split('.')
        if len(minutes[0])<2: 
            m = minutes[0] +'0'
        else: 
            m = minutes[0]
        #print(date, h, m)
        data_f = date+' '+h+':'+m+':'+'00'
        #print(data_f)
        cell_values.append(row['nr_people'])
        dates4dec.append(data_f) 
        
    dict_i = {'ds': dates4dec, 'y':cell_values}
    data4deco = pd.DataFrame(dict_i, index=None, columns=None)  
   
    data4deco['ds'] = pd.to_datetime(data4deco['ds'])
    data4deco = data4deco.set_index('ds')
   
    decomp = decompose(data4deco['y'], period=24)
   
    trend = decomp.trend.values
    #print(trend[:10])
    seasonal = decomp.seasonal.values
    residual = decomp.resid.values
    
        
    trend = trend.reshape((len(trend), 1))
    seasonal = seasonal.reshape((len(seasonal), 1))
    residual = residual.reshape((len(residual), 1))
     
    seasonal = seasonal.astype(int)    
    residual = residual.astype(int)
    trend = trend.astype(int)
    #print(trend[:10])
    trend_data.append(trend)
    seasonal_data.append(seasonal)
    residual_data.append(residual)
# Out:
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# 2952
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-48-cc77dc931252> in <module>
#       9     k = k.iloc[::4,:]
#      10     print(len(k))
# ---> 11     for index, row in k.iterrows():
#      12
#      13         date = row['date']
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in iterrows(self)
#     892         klass = self._constructor_sliced
#     893         for k, v in zip(self.index, self.values):
# --> 894             s = klass(v, index=columns, name=k)
#     895             yield k, s
#     896
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     309                     data = data.copy()
#     310             else:
# --> 311                 data = sanitize_array(data, index, dtype, copy, raise_cast_failure=True)
#     312
#     313                 data = SingleBlockManager(data, index, fastpath=True)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure)
#     662         else:
#     663             # we will try to copy be-definition here
# --> 664             subarr = _try_cast(data, dtype, copy, raise_cast_failure)
#     665
#     666     elif isinstance(data, ExtensionArray):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in _try_cast(arr, dtype, copy, raise_cast_failure)
#     790         ):
#     791             subarr = construct_1d_object_array_from_listlike(subarr)
# --> 792         elif not is_extension_type(subarr):
#     793             subarr = construct_1d_ndarray_preserving_na(subarr, dtype, copy=copy)
#     794     except OutOfBoundsDatetime:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/dtypes/common.py in is_extension_type(arr)
#    1734     if is_categorical(arr):
#    1735         return True
# -> 1736     elif is_sparse(arr):
#    1737         return True
#    1738     elif is_datetime64tz_dtype(arr):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/dtypes/common.py in is_sparse(arr)
#     309     True
#     310     """
# --> 311     from pandas.core.arrays.sparse import SparseDtype
#     312
#     313     dtype = getattr(arr, "dtype", arr)
#
# ~/anaconda3/lib/python3.7/importlib/_bootstrap.py in _handle_fromlist(module, fromlist, import_, recursive)
#
# KeyboardInterrupt:

# %%
final_data_trend = np.hstack((trend_data))
final_data_seasonal = np.hstack((seasonal_data))
final_data_residual = np.hstack((residual_data))

# %%
# split a multivariate sequence into samples
def split_sequences(sequences, n_steps_in, n_steps_out):
  X, y = list(), list()
  for i in range(len(sequences)):
      # find the end of this pattern
      end_ix = i + n_steps_in
      out_end_ix = end_ix + n_steps_out
      # check if we are beyond the dataset
      if out_end_ix > len(sequences):
          break
      # gather input and output parts of the pattern
      seq_x, seq_y = sequences[i:end_ix, :], sequences[end_ix:out_end_ix, :]
      X.append(seq_x)
      y.append(seq_y)
  return np.array(X), np.array(y)

# choose a number of time steps
n_steps_in, n_steps_out = 24, 12

# %%
# convert into input/output
X_seasonal, y_seasonal = split_sequences(final_data_seasonal, n_steps_in, n_steps_out)
X_trend, y_trend = split_sequences(final_data_trend, n_steps_in, n_steps_out)
X_residual, y_residual = split_sequences(final_data_residual, n_steps_in, n_steps_out)

count = 0
for i in range(len(X_seasonal)):
    count += 1
    print('inizia iterazione ', i)
    print(X_seasonal[i], y_seasonal[i])
    if count > 1: break

# %%
split_train_test = int(len(X_trend)*0.75)
train_X_trend, test_X_trend = X_trend[:split_train_test], X_trend[split_train_test:]
train_y_trend, test_y_trend = y_trend[:split_train_test], y_trend[split_train_test:]
print(len(train_X_trend), len(train_y_trend), len(test_X_trend), len(test_y_trend))

# %%
# the dataset knows the number of features, e.g. 2
n_features_trend = train_X_trend.shape[2]

# define model
model_trend = Sequential()
model_trend.add(LSTM(200, activation='relu', input_shape=(n_steps_in, n_features_trend))) 
model_trend.add(RepeatVector(n_steps_out))
model_trend.add(LSTM(200, activation='relu', return_sequences=True)) 
model_trend.add(TimeDistributed(Dense(n_features_trend)))
model_trend.compile(optimizer='adam', loss='mse',  metrics=[metrics.mae, 'accuracy'])
# fit model
model_trend.fit(train_X_trend, train_y_trend, epochs=40, verbose=2)

# %%
# flatten output
n_output_seasonal = y_seasonal.shape[1] * y_seasonal.shape[2]
y_seasonal = y_seasonal.reshape((y_seasonal.shape[0], n_output_seasonal))
# the dataset knows the number of features, e.g. 2
n_features_seasonal = X_seasonal.shape[2]

# flatten output
n_output_residual = y_residual.shape[1] * y_residual.shape[2]
y_residual = y_residual.reshape((y_residual.shape[0], n_output_residual))
# the dataset knows the number of features, e.g. 2
n_features_residual = X_residual.shape[2]

# %%
train_X_seasonal, test_X_seasonal = X_seasonal[:split_train_test], X_seasonal[split_train_test:]
train_y_seasonal, test_y_seasonal = y_seasonal[:split_train_test], y_seasonal[split_train_test:]
print(len(train_X_seasonal), len(train_y_seasonal), len(test_X_seasonal), len(test_y_seasonal))

train_X_residual, test_X_residual = X_residual[:split_train_test], X_residual[split_train_test:]
train_y_residual, test_y_residual = y_residual[:split_train_test], y_residual[split_train_test:]
print(len(train_X_residual), len(train_y_residual), len(test_X_residual), len(test_y_residual))

# %%
# define model
model_seasonal = Sequential()
model_seasonal.add(Conv1D(filters=64, kernel_size=2, activation='relu', input_shape=(n_steps_in, n_features_seasonal)))
model_seasonal.add(MaxPooling1D(pool_size=2))
model_seasonal.add(Flatten())
model_seasonal.add(Dense(500, activation='relu')) 
model_seasonal.add(Dense(n_output_seasonal))
model_seasonal.compile(optimizer='adam',  loss='mse',  metrics=[metrics.mae, 'accuracy'])
# fit model
model_seasonal.fit(train_X_seasonal, train_y_seasonal, epochs=200, verbose=2)

# %%
# define model
model_residual = Sequential()
model_residual.add(Conv1D(filters=64, kernel_size=2, activation='relu', input_shape=(n_steps_in, n_features_residual)))
model_residual.add(MaxPooling1D(pool_size=2))
model_residual.add(Flatten())
model_residual.add(Dense(500, activation='relu')) 
model_residual.add(Dense(n_output_residual))
model_residual.compile(optimizer='adam',  loss='mse',  metrics=[metrics.mae, 'accuracy'])
# fit model
model_residual.fit(train_X_residual, train_y_residual, epochs=200, verbose=2)

# %%
# predict and compute error
predicted_trend = np.array([])
for i in range(len(test_X_trend)):
    x_input = test_X_trend[i].reshape((1, n_steps_in, n_features_trend))
    yhat = model_trend.predict(x_input, verbose=0)
    #print(yhat[0])
    predicted_trend = np.append(predicted_trend, yhat[0])  
    
    
predicted_residual = np.array([])
for i in range(len(test_X_residual)):
    x_input = test_X_residual[i].reshape((1, n_steps_in, n_features_residual))
    yhat = model_residual.predict(x_input, verbose=0)
    #print(yhat[0])
    predicted_residual = np.append(predicted_residual, yhat[0]) 

# predict and compute error
predicted_seasonal = np.array([])
for i in range(len(test_X_seasonal)):
    x_input = test_X_seasonal[i].reshape((1, n_steps_in, n_features_seasonal))
    yhat = model_seasonal.predict(x_input, verbose=0)
    #print(yhat[0])
    predicted_seasonal = np.append(predicted_seasonal, yhat[0])

# %%
predicted_final = predicted_trend + predicted_seasonal + predicted_residual
len(predicted_final)

# %%
num_data = []
## prepare dataset
for i, k in agg_by_cell:
    cell_i = agg_by_cell.get_group(i)
    #cell_i = cell_i.iloc[::4, :]
    # define input sequence
    series_i = cell_i['nr_people'].values
    series_i = series_i.reshape((len(series_i), 1))
    num_data.append(series_i)

# %%
final_data = hstack((num_data))
final_data.shape

# %%
X, y = split_sequences(final_data, n_steps_in, n_steps_out)

# %%
n_output = y.shape[1] * y.shape[2]
y = y.reshape((y.shape[0], n_output))

# the dataset knows the number of features, e.g. 2
n_features = X.shape[2]

# %%
train_X, test_X = X[:split_train_test], X[split_train_test:]
train_y, test_y = y[:split_train_test], y[split_train_test:]
print(len(train_X), len(train_y), len(test_X), len(test_y))

# %%
exp_y = test_y.reshape((test_y.shape[0] * test_y.shape[1])) 
len(exp_y)

# %%
difference = abs(predicted_final - exp_y)
print('Mean Absolute Error = ', np.mean(difference))
plt.figure(figsize = (14,2))
plt.boxplot(difference, vert = False)
plt.show()
