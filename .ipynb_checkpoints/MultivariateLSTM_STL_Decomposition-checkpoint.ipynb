# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error 
from math import sqrt
from numpy import hstack
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
import warnings 
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split
from keras import metrics
from stldecompose import decompose, forecast
from stldecompose.forecast_funcs import (naive,
                                         drift, 
                                         mean, 
                                         seasonal_naive)

data = pd.read_csv('/Users/alket/Desktop/dati/new_data_backfill_forwfill.csv',index_col = 0)

# aggregazione dati per celle
agg_by_cell = data.groupby(by = ['cell_num'])

# %%
trend_data = []
residual_data = []
seasonal_data = []

for i, k in agg_by_cell:
    
    dates4dec = []
    cell_values = []
    k = k.iloc[::4,:]
    print(len(k))
    for index, row in k.iterrows():
        
        date = row['date']
        h = str(row['hours'])
   
        h = h.split('.')
    
        if len(h[0])<2:
            h = h[1]+h[0]
        else: 
            h = h[0]
   
        minutes = str(row['minutes'])
        m = ''
        minutes = minutes.split('.')
        if len(minutes[0])<2: 
            m = minutes[0] +'0'
        else: 
            m = minutes[0]
        #print(date, h, m)
        data_f = date+' '+h+':'+m+':'+'00'
        #print(data_f)
        cell_values.append(row['nr_people'])
        dates4dec.append(data_f) 
        
    dict_i = {'ds': dates4dec, 'y':cell_values}
    data4deco = pd.DataFrame(dict_i, index=None, columns=None)  
   
    data4deco['ds'] = pd.to_datetime(data4deco['ds'])
    data4deco = data4deco.set_index('ds')
   
    decomp = decompose(data4deco['y'], period=24)
   
    trend = decomp.trend.values
    #print(trend[:10])
    seasonal = decomp.seasonal.values
    residual = decomp.resid.values
    
        
    trend = trend.reshape((len(trend), 1))
    seasonal = seasonal.reshape((len(seasonal), 1))
    residual = residual.reshape((len(residual), 1))
     
    seasonal = seasonal.astype(int)    
    residual = residual.astype(int)
    trend = trend.astype(int)
    #print(trend[:10])
    trend_data.append(trend)
    seasonal_data.append(seasonal)
    residual_data.append(residual)
# Out:
# 2952
# [36.58638794 36.59382377 36.6012596  36.60869543 36.61613126 36.62356709
#  36.63100291 36.63843874 36.64587457 36.6533104 ]
# [[36]
#  [36]
#  [36]
#  [36]
#  [36]
#  [36]
#  [36]
#  [36]
#  [36]
#  [36]]
# 2952
# [40.20226828 40.21005418 40.21784008 40.22562598 40.23341188 40.24119778
#  40.24898368 40.25676957 40.26455547 40.27234137]
# [[40]
#  [40]
#  [40]
#  [40]
#  [40]
#  [40]
#  [40]
#  [40]
#  [40]
#  [40]]
# 2952
# [42.11363646 42.12121945 42.12880243 42.13638542 42.14396841 42.1515514
#  42.15913438 42.16671737 42.17430036 42.18188334]
# [[42]
#  [42]
#  [42]
#  [42]
#  [42]
#  [42]
#  [42]
#  [42]
#  [42]
#  [42]]
# 2952
# [42.5161606  42.52357758 42.53099456 42.53841154 42.54582852 42.5532455
#  42.56066248 42.56807946 42.57549645 42.58291343]
# [[42]
#  [42]
#  [42]
#  [42]
#  [42]
#  [42]
#  [42]
#  [42]
#  [42]
#  [42]]
# 2952
# [42.22365192 42.2303766  42.23710129 42.24382598 42.25055067 42.25727536
#  42.26400004 42.27072473 42.27744942 42.28417411]
# [[42]
#  [42]
#  [42]
#  [42]
#  [42]
#  [42]
#  [42]
#  [42]
#  [42]
#  [42]]
# 2952
# [41.73186664 41.73667929 41.74149194 41.7463046  41.75111725 41.7559299
#  41.76074255 41.7655552  41.77036786 41.77518051]
# [[41]
#  [41]
#  [41]
#  [41]
#  [41]
#  [41]
#  [41]
#  [41]
#  [41]
#  [41]]
# 2952
# [43.5547241  43.55566168 43.55659925 43.55753683 43.55847441 43.55941199
#  43.56034957 43.56128714 43.56222472 43.5631623 ]
# [[43]
#  [43]
#  [43]
#  [43]
#  [43]
#  [43]
#  [43]
#  [43]
#  [43]
#  [43]]
# 2952
# [43.74343088 43.74263698 43.74184308 43.74104919 43.74025529 43.7394614
#  43.7386675  43.73787361 43.73707971 43.73628582]
# [[43]
#  [43]
#  [43]
#  [43]
#  [43]
#  [43]
#  [43]
#  [43]
#  [43]
#  [43]]
# 2952
# [43.77098881 43.77019077 43.76939273 43.76859469 43.76779665 43.76699861
#  43.76620057 43.76540254 43.7646045  43.76380646]
# [[43]
#  [43]
#  [43]
#  [43]
#  [43]
#  [43]
#  [43]
#  [43]
#  [43]
#  [43]]
# 2952
#
]
#  [162]
#  [162]
#  [162]
#  [162]
#  [162]
#  [162]
#  [162]
#  [162]
#  [162]]
# 2952
# [190.67417906 190.67314692 190.67211478 190.67108264 190.6700505
#  190.66901836 190.66798622 190.66695408 190.66592194 190.6648898 ]
# [[190]
#  [190]
#  [190]
#  [190]
#  [190]
#  [190]
#  [190]
#  [190]
#  [190]
#  [190]]
# 2952
# [95.91540845 95.91377718 95.9121459  95.91051462 95.90888334 95.90725206
#  95.90562078 95.9039895  95.90235822 95.90072694]
# [[95]
#  [95]
#  [95]
#  [95]
#  [95]
#  [95]
#  [95]
#  [95]
#  [95]
#  [95]]
# 2952
# [18.04995853 18.0499954  18.05003226 18.05006912 18.05010599 18.05014285
#  18.05017972 18.05021658 18.05025345 18.05029031]
# [[18]
#  [18]
#  [18]
#  [18]
#  [18]
#  [18]
#  [18]
#  [18]
#  [18]
#  [18]]
# 2952
# [17.84715727 17.84707229 17.84698732 17.84690234 17.84681736 17.84673239
#  17.84664741 17.84656243 17.84647746 17.84639248]
# [[17]
#  [17]
#  [17]
#  [17]
#  [17]
#  [17]
#  [17]
#  [17]
#  [17]
#  [17]]
# 2952
# [17.58359567 17.58400774 17.58441981 17.58483188 17.58524395 17.58565602
#  17.5860681  17.58648017 17.58689224 17.58730431]
# [[17]
#  [17]
#  [17]
#  [17]
#  [17]
#  [17]
#  [17]
#  [17]
#  [17]
#  [17]]
# 2952
# [18.18163866 18.18212283 18.182607   18.18309118 18.18357535 18.18405952
#  18.1845437  18.18502787 18.18551204 18.18599622]
# [[18]
#  [18]
#  [18]
#  [18]
#  [18]
#  [18]
#  [18]
#  [18]
#  [18]
#  [18]]
# 2952
# [18.23559231 18.23623274 18.23687317 18.2375136  18.23815403 18.23879446
#  18.23943489 18.24007531 18.24071574 18.24135617]
# [[18]
#  [18]
#  [18]
#  [18]
#  [18]
#  [18]
#  [18]
#  [18]
#  [18]
#  [18]]
# 2952
# [114.76425249 114.7726181  114.78098372 114.78934933 114.79771494
#  114.80608056 114.81444617 114.82281178 114.8311774  114.83954301]
# [[114]
#  [114]
#  [114]
#  [114]
#  [114]
#  [114]
#  [114]
#  [114]
#  [114]
#  [114]]
# 2952
# [38.44265917 38.44562933 38.44859949 38.45156965 38.45453982 38.45750998
#  38.46048014 38.4634503  38.46642046 38.46939062]
# [[38]
#  [38]
#  [38]
#  [38]
#  [38]
#  [38]
#  [38]
#  [38]
#  [38]
#  [38]]

# %%
final_data_trend = hstack((trend_data))
final_data_seasonal = hstack((seasonal_data))
final_data_residual = hstack((residual_data))

# %%
# split a multivariate sequence into samples
def split_sequences(sequences, n_steps_in, n_steps_out):
  X, y = list(), list()
  for i in range(len(sequences)):
      # find the end of this pattern
      end_ix = i + n_steps_in
      out_end_ix = end_ix + n_steps_out
      # check if we are beyond the dataset
      if out_end_ix > len(sequences):
          break
      # gather input and output parts of the pattern
      seq_x, seq_y = sequences[i:end_ix, :], sequences[end_ix:out_end_ix, :]
      X.append(seq_x)
      y.append(seq_y)
  return np.array(X), np.array(y)

# choose a number of time steps
n_steps_in, n_steps_out = 24, 12

# %%
# convert into input/output
X_seasonal, y_seasonal = split_sequences(final_data_seasonal, n_steps_in, n_steps_out)
X_trend, y_trend = split_sequences(final_data_trend, n_steps_in, n_steps_out)
X_residual, y_residual = split_sequences(final_data_residual, n_steps_in, n_steps_out)

count = 0
for i in range(len(X_seasonal)):
    count += 1
    print('inizia iterazione ', i)
    print(X_seasonal[i], y_seasonal[i])
    if count > 1: break
# Out:
# inizia iterazione  0
# [[  2   1   1 ...   0   1   0]
#  [ -3  -4  -5 ...   0   1   0]
#  [ -7 -10 -11 ...   0   2   0]
#  ...
#  [ 12  13  14 ...   0   0   0]
#  [  7   7   7 ...   0   1   0]
#  [  3   3   2 ...   0   1   0]] [[  2   1   1 ...   0   1   0]
#  [ -3  -4  -5 ...   0   1   0]
#  [ -7 -10 -11 ...   0   2   0]
#  ...
#  [-14 -15 -15 ...   0   6   2]
#  [ -6  -6  -6 ...   0   4   1]
#  [ -4  -3  -3 ...   0   0   0]]
# inizia iterazione  1
# [[ -3  -4  -5 ...   0   1   0]
#  [ -7 -10 -11 ...   0   2   0]
#  [-11 -13 -14 ...   0   2   0]
#  ...
#  [  7   7   7 ...   0   1   0]
#  [  3   3   2 ...   0   1   0]
#  [  2   1   1 ...   0   1   0]] [[ -3  -4  -5 ...   0   1   0]
#  [ -7 -10 -11 ...   0   2   0]
#  [-11 -13 -14 ...   0   2   0]
#  ...
#  [ -6  -6  -6 ...   0   4   1]
#  [ -4  -3  -3 ...   0   0   0]
#  [ -1  -1  -1 ...   0  -2   0]]

# %%
# flatten output

# %%
split_train_test = int(len(X_trend)*0.75)
train_X_trend, test_X_trend = X_trend[:split_train_test], X_trend[split_train_test:]
train_y_trend, test_y_trend = y_trend[:split_train_test], y_trend[split_train_test:]
print(len(train_X_trend), len(train_y_trend), len(test_X_trend), len(test_y_trend))

train_X_seasonal, test_X_seasonal = X_seasonal[:split_train_test], X_seasonal[split_train_test:]
train_y_seasonal, test_y_seasonal = y_seasonal[:split_train_test], y_seasonal[split_train_test:]
print(len(train_X_seasonal), len(train_y_seasonal), len(test_X_seasonal), len(test_y_seasonal))

train_X_residual, test_X_residual = X_residual[:split_train_test], X_residual[split_train_test:]
train_y_residual, test_y_residual = y_residual[:split_train_test], y_residual[split_train_test:]
print(len(train_X_residual), len(train_y_residual), len(test_X_residual), len(test_y_residual))
# Out:
# 2187 2187 730 730
# 2187 2187 730 730
# 2187 2187 730 730

# %%
# the dataset knows the number of features, e.g. 2
n_features_trend = train_X_trend.shape[2]

# define model
model_trend = Sequential()
model_trend.add(LSTM(200, activation='relu', input_shape=(n_steps_in, n_features_trend))) 
model_trend.add(RepeatVector(n_steps_out))
model_trend.add(LSTM(200, activation='relu', return_sequences=True)) 
model_trend.add(TimeDistributed(Dense(n_features_trend)))
model_trend.compile(optimizer='adam', loss='mse',  metrics=[metrics.mae, 'accuracy'])
# fit model
model_trend.fit(train_X_trend, train_y_trend, epochs=40, verbose=2)
# Out:
# Epoch 1/40
# 69/69 - 2s - loss: 1416147.1250 - mean_absolute_error: 778.5333 - accuracy: 0.1392
# Epoch 2/40
# 69/69 - 2s - loss: 185403.5156 - mean_absolute_error: 286.4844 - accuracy: 0.3639
# Epoch 3/40
# 69/69 - 2s - loss: 809632.8750 - mean_absolute_error: 476.4636 - accuracy: 0.3941
# Epoch 4/40
# 69/69 - 3s - loss: 25786.9766 - mean_absolute_error: 111.1862 - accuracy: 0.4832
# Epoch 5/40
# 69/69 - 2s - loss: 9147.2490 - mean_absolute_error: 68.1127 - accuracy: 0.6373
# Epoch 6/40
# 69/69 - 2s - loss: 4772.9243 - mean_absolute_error: 50.6360 - accuracy: 0.6189
# Epoch 7/40
# 69/69 - 2s - loss: 2992.5981 - mean_absolute_error: 40.6457 - accuracy: 0.6265
# Epoch 8/40
# 69/69 - 2s - loss: 2114.9382 - mean_absolute_error: 34.1732 - accuracy: 0.6332
# Epoch 9/40
# 69/69 - 2s - loss: 1516.5542 - mean_absolute_error: 28.6325 - accuracy: 0.6351
# Epoch 10/40
# 69/69 - 2s - loss: 1088.8583 - mean_absolute_error: 23.8013 - accuracy: 0.6763
# Epoch 11/40
# 69/69 - 2s - loss: 840.7161 - mean_absolute_error: 20.6373 - accuracy: 0.6966
# Epoch 12/40
# 69/69 - 3s - loss: 714.1268 - mean_absolute_error: 18.9052 - accuracy: 0.6966
# Epoch 13/40
# 69/69 - 3s - loss: 620.5742 - mean_absolute_error: 17.5238 - accuracy: 0.6966
# Epoch 14/40
# 69/69 - 3s - loss: 556.8070 - mean_absolute_error: 16.5344 - accuracy: 0.6966
# Epoch 15/40
# 69/69 - 3s - loss: 500.9949 - mean_absolute_error: 15.6133 - accuracy: 0.6966
# Epoch 16/40
# 69/69 - 3s - loss: 454.8013 - mean_absolute_error: 14.7993 - accuracy: 0.6966
# Epoch 17/40
# 69/69 - 3s - loss: 417.0005 - mean_absolute_error: 14.1107 - accuracy: 0.6966
# Epoch 18/40
# 69/69 - 3s - loss: 382.6884 - mean_absolute_error: 13.4357 - accuracy: 0.6966
# Epoch 19/40
# 69/69 - 3s - loss: 359.0576 - mean_absolute_error: 12.9424 - accuracy: 0.6966
# Epoch 20/40
# 69/69 - 2s - loss: 338.5866 - mean_absolute_error: 12.5130 - accuracy: 0.6966
# Epoch 21/40
# 69/69 - 2s - loss: 320.1821 - mean_absolute_error: 12.0997 - accuracy: 0.6966
# Epoch 22/40
# 69/69 - 2s - loss: 305.8856 - mean_absolute_error: 11.7924 - accuracy: 0.6966
# Epoch 23/40
# 69/69 - 2s - loss: 293.6234 - mean_absolute_error: 11.4879 - accuracy: 0.6966
# Epoch 24/40
# 69/69 - 2s - loss: 281.7485 - mean_absolute_error: 11.2246 - accuracy: 0.6966
# Epoch 25/40
# 69/69 - 3s - loss: 272.0073 - mean_absolute_error: 10.9673 - accuracy: 0.6966
# Epoch 26/40
# 69/69 - 3s - loss: 265.1417 - mean_absolute_error: 10.8089 - accuracy: 0.6966
# Epoch 27/40
# 69/69 - 3s - loss: 256.5544 - mean_absolute_error: 10.5757 - accuracy: 0.6966
# Epoch 28/40
# 69/69 - 2s - loss: 253.0408 - mean_absolute_error: 10.4746 - accuracy: 0.6966
# Epoch 29/40
# 69/69 - 2s - loss: 247.4927 - mean_absolute_error: 10.3376 - accuracy: 0.6966
# Epoch 30/40
# 69/69 - 2s - loss: 241.5654 - mean_absolute_error: 10.1794 - accuracy: 0.6966
# Epoch 31/40
# 69/69 - 2s - loss: 236.3596 - mean_absolute_error: 10.0454 - accuracy: 0.6966
# Epoch 32/40
# 69/69 - 2s - loss: 233.7438 - mean_absolute_error: 9.9675 - accuracy: 0.6966
# Epoch 33/40
# 69/69 - 2s - loss: 230.1887 - mean_absolute_error: 9.8870 - accuracy: 0.6966
# Epoch 34/40
# 69/69 - 3s - loss: 225.6685 - mean_absolute_error: 9.7488 - accuracy: 0.6966
# Epoch 35/40
# 69/69 - 3s - loss: 222.9265 - mean_absolute_error: 9.6874 - accuracy: 0.6966
# Epoch 36/40
# 69/69 - 3s - loss: 220.2853 - mean_absolute_error: 9.6393 - accuracy: 0.6966
# Epoch 37/40
# 69/69 - 3s - loss: 216.7375 - mean_absolute_error: 9.5066 - accuracy: 0.6966
# Epoch 38/40
# 69/69 - 3s - loss: 215.2951 - mean_absolute_error: 9.4650 - accuracy: 0.6966
# Epoch 39/40
# 69/69 - 2s - loss: 212.7594 - mean_absolute_error: 9.4237 - accuracy: 0.6966
# Epoch 40/40
# 69/69 - 3s - loss: 208.3053 - mean_absolute_error: 9.2919 - accuracy: 0.6966

# %%
# the dataset knows the number of features, e.g. 2
n_features_residual = train_X_residual.shape[2]

# define model
model_residual = Sequential()
model_residual.add(LSTM(200, activation='relu', input_shape=(n_steps_in, n_features_residual))) 
model_residual.add(RepeatVector(n_steps_out))
model_residual.add(LSTM(200, activation='relu', return_sequences=True)) 
model_residual.add(TimeDistributed(Dense(n_features_residual)))
model_residual.compile(optimizer='adam', loss='mse',  metrics=[metrics.mae, 'accuracy'])
# fit model
model_residual.fit(train_X_residual, train_y_residual, epochs=40, verbose=2)
# Out:
# Epoch 1/40
# 69/69 - 2s - loss: 26749.8887 - mean_absolute_error: 79.3433 - accuracy: 0.0043
# Epoch 2/40
# 69/69 - 2s - loss: 7810.2104 - mean_absolute_error: 46.5947 - accuracy: 0.0104
# Epoch 3/40
# 69/69 - 2s - loss: 2814.5725 - mean_absolute_error: 30.0675 - accuracy: 0.0189
# Epoch 4/40
# 69/69 - 2s - loss: 2642.8396 - mean_absolute_error: 26.6160 - accuracy: 0.0349
# Epoch 5/40
# 69/69 - 2s - loss: 2547.4553 - mean_absolute_error: 19.7979 - accuracy: 0.0730
# Epoch 6/40
# 69/69 - 2s - loss: 942.8300 - mean_absolute_error: 13.5228 - accuracy: 0.0293
# Epoch 7/40
# 69/69 - 2s - loss: 620.4762 - mean_absolute_error: 11.5352 - accuracy: 0.1108
# Epoch 8/40
# 69/69 - 2s - loss: 548.9789 - mean_absolute_error: 10.9337 - accuracy: 0.1170
# Epoch 9/40
# 69/69 - 3s - loss: 568.2584 - mean_absolute_error: 10.8200 - accuracy: 0.1242
# Epoch 10/40
# 69/69 - 3s - loss: 536.6214 - mean_absolute_error: 10.8361 - accuracy: 0.1328
# Epoch 11/40
# 69/69 - 3s - loss: 538.9777 - mean_absolute_error: 10.8116 - accuracy: 0.1450
# Epoch 12/40
# 69/69 - 3s - loss: 525.6140 - mean_absolute_error: 10.6113 - accuracy: 0.1506
# Epoch 13/40
# 69/69 - 3s - loss: 526.8409 - mean_absolute_error: 10.5888 - accuracy: 0.1449
# Epoch 14/40
# 69/69 - 3s - loss: 538.4773 - mean_absolute_error: 10.6148 - accuracy: 0.1531
# Epoch 15/40
# 69/69 - 3s - loss: 532.5709 - mean_absolute_error: 10.5926 - accuracy: 0.1615
# Epoch 16/40
# 69/69 - 2s - loss: 523.0233 - mean_absolute_error: 10.5464 - accuracy: 0.1533
# Epoch 17/40
# 69/69 - 2s - loss: 522.7635 - mean_absolute_error: 10.5159 - accuracy: 0.1600
# Epoch 18/40
# 69/69 - 2s - loss: 540.2734 - mean_absolute_error: 10.5587 - accuracy: 0.1541
# Epoch 19/40
# 69/69 - 2s - loss: 516.5610 - mean_absolute_error: 10.3995 - accuracy: 0.1510
# Epoch 20/40
# 69/69 - 2s - loss: 515.1974 - mean_absolute_error: 10.3922 - accuracy: 0.1542
# Epoch 21/40
# 69/69 - 2s - loss: 516.6572 - mean_absolute_error: 10.4276 - accuracy: 0.1534
# Epoch 22/40
# 69/69 - 2s - loss: 514.6928 - mean_absolute_error: 10.4097 - accuracy: 0.1600
# Epoch 23/40
# 69/69 - 2s - loss: 517.2079 - mean_absolute_error: 10.4620 - accuracy: 0.1540
# Epoch 24/40
# 69/69 - 2s - loss: 513.4261 - mean_absolute_error: 10.4058 - accuracy: 0.1414
# Epoch 25/40
# 69/69 - 3s - loss: 515.8685 - mean_absolute_error: 10.4265 - accuracy: 0.1450
# Epoch 26/40
# 69/69 - 3s - loss: 514.9730 - mean_absolute_error: 10.3957 - accuracy: 0.1585
# Epoch 27/40
# 69/69 - 3s - loss: 518.6138 - mean_absolute_error: 10.4396 - accuracy: 0.1542
# Epoch 28/40
# 69/69 - 3s - loss: 537.8193 - mean_absolute_error: 10.6629 - accuracy: 0.1260
# Epoch 29/40
# 69/69 - 3s - loss: 2574.4729 - mean_absolute_error: 17.1551 - accuracy: 0.1284
# Epoch 30/40
# 69/69 - 3s - loss: 861.0927 - mean_absolute_error: 13.1045 - accuracy: 0.0937
# Epoch 31/40
# 69/69 - 2s - loss: 574.5712 - mean_absolute_error: 11.1244 - accuracy: 0.1191
# Epoch 32/40
# 69/69 - 2s - loss: 534.3555 - mean_absolute_error: 10.7208 - accuracy: 0.1183
# Epoch 33/40
# 69/69 - 3s - loss: 526.9288 - mean_absolute_error: 10.5908 - accuracy: 0.1243
# Epoch 34/40
# 69/69 - 3s - loss: 523.3109 - mean_absolute_error: 10.5968 - accuracy: 0.1143
# Epoch 35/40
# 69/69 - 3s - loss: 535.6548 - mean_absolute_error: 10.7373 - accuracy: 0.1253
# Epoch 36/40
# 69/69 - 3s - loss: 531.1649 - mean_absolute_error: 10.7917 - accuracy: 0.1168
# Epoch 37/40
# 69/69 - 3s - loss: 523.8694 - mean_absolute_error: 10.6201 - accuracy: 0.1193
# Epoch 38/40
# 69/69 - 3s - loss: 530.0045 - mean_absolute_error: 10.6026 - accuracy: 0.1280
# Epoch 39/40
# 69/69 - 3s - loss: 573.1807 - mean_absolute_error: 10.7687 - accuracy: 0.1283
# Epoch 40/40
# 69/69 - 3s - loss: 885.6547 - mean_absolute_error: 13.1188 - accuracy: 0.1003

# %%
# the dataset knows the number of features, e.g. 2
n_features_seasonal = train_X_seasonal.shape[2]

# define model
model_seasonal = Sequential()
model_seasonal.add(LSTM(200, activation='relu', input_shape=(n_steps_in, n_features_seasonal))) 
model_seasonal.add(RepeatVector(n_steps_out))
model_seasonal.add(LSTM(200, activation='relu', return_sequences=True)) 
model_seasonal.add(TimeDistributed(Dense(n_features_seasonal)))
model_seasonal.compile(optimizer='adam', loss='mse',  metrics=[metrics.mae, 'accuracy'])
# fit model
model_seasonal.fit(train_X_seasonal, train_y_seasonal, epochs=40, verbose=2)
# Out:
# Epoch 1/40
# 69/69 - 2s - loss: 33615.3750 - mean_absolute_error: 118.9133 - accuracy: 0.0102
# Epoch 2/40
# 69/69 - 2s - loss: 20531.2090 - mean_absolute_error: 96.2890 - accuracy: 0.0161
# Epoch 3/40
# 69/69 - 2s - loss: 10636.7578 - mean_absolute_error: 65.0578 - accuracy: 0.0618
# Epoch 4/40
# 69/69 - 2s - loss: 6488.4985 - mean_absolute_error: 44.5621 - accuracy: 0.0706
# Epoch 5/40
# 69/69 - 2s - loss: 5723.5527 - mean_absolute_error: 40.2225 - accuracy: 0.0782
# Epoch 6/40
# 69/69 - 2s - loss: 4047.9016 - mean_absolute_error: 33.1298 - accuracy: 0.1070
# Epoch 7/40
# 69/69 - 2s - loss: 2326.8916 - mean_absolute_error: 23.9438 - accuracy: 0.1457
# Epoch 8/40
# 69/69 - 2s - loss: 2009.1045 - mean_absolute_error: 21.6642 - accuracy: 0.0849
# Epoch 9/40
# 69/69 - 2s - loss: 1631.2153 - mean_absolute_error: 20.7139 - accuracy: 0.0914
# Epoch 10/40
# 69/69 - 2s - loss: 1376.1379 - mean_absolute_error: 18.7499 - accuracy: 0.1709
# Epoch 11/40
# 69/69 - 2s - loss: 1412.9132 - mean_absolute_error: 18.4132 - accuracy: 0.1989
# Epoch 12/40
# 69/69 - 2s - loss: 1255.5514 - mean_absolute_error: 16.9883 - accuracy: 0.2092
# Epoch 13/40
# 69/69 - 2s - loss: 1254.8179 - mean_absolute_error: 16.9871 - accuracy: 0.1965
# Epoch 14/40
# 69/69 - 2s - loss: 1258.8810 - mean_absolute_error: 16.9139 - accuracy: 0.2829
# Epoch 15/40
# 69/69 - 2s - loss: 1225.1440 - mean_absolute_error: 16.6839 - accuracy: 0.2964
# Epoch 16/40
# 69/69 - 2s - loss: 1210.5420 - mean_absolute_error: 16.5388 - accuracy: 0.3860
# Epoch 17/40
# 69/69 - 2s - loss: 1063.0079 - mean_absolute_error: 15.3207 - accuracy: 0.4118
# Epoch 18/40
# 69/69 - 2s - loss: 1096.8160 - mean_absolute_error: 15.2661 - accuracy: 0.4590
# Epoch 19/40
# 69/69 - 2s - loss: 1355.3159 - mean_absolute_error: 17.3707 - accuracy: 0.4401
# Epoch 20/40
# 69/69 - 2s - loss: 1196.6838 - mean_absolute_error: 16.2320 - accuracy: 0.4814
# Epoch 21/40
# 69/69 - 3s - loss: 1144.7152 - mean_absolute_error: 15.8521 - accuracy: 0.4770
# Epoch 22/40
# 69/69 - 2s - loss: 981.4366 - mean_absolute_error: 14.5539 - accuracy: 0.5298
# Epoch 23/40
# 69/69 - 2s - loss: 930.4717 - mean_absolute_error: 14.2115 - accuracy: 0.5977
# Epoch 24/40
# 69/69 - 3s - loss: 925.1058 - mean_absolute_error: 14.2364 - accuracy: 0.5906
# Epoch 25/40
# 69/69 - 3s - loss: 794.8357 - mean_absolute_error: 12.9467 - accuracy: 0.6340
# Epoch 26/40
# 69/69 - 2s - loss: 849.7770 - mean_absolute_error: 13.5091 - accuracy: 0.6154
# Epoch 27/40
# 69/69 - 2s - loss: 767.9806 - mean_absolute_error: 12.8247 - accuracy: 0.6325
# Epoch 28/40
# 69/69 - 3s - loss: 721.8995 - mean_absolute_error: 12.3499 - accuracy: 0.6268
# Epoch 29/40
# 69/69 - 3s - loss: 679.7337 - mean_absolute_error: 11.8778 - accuracy: 0.6544
# Epoch 30/40
# 69/69 - 2s - loss: 647.5829 - mean_absolute_error: 11.5387 - accuracy: 0.6587
# Epoch 31/40
# 69/69 - 3s - loss: 609.5620 - mean_absolute_error: 11.1408 - accuracy: 0.6646
# Epoch 32/40
# 69/69 - 3s - loss: 567.5195 - mean_absolute_error: 10.6800 - accuracy: 0.6635
# Epoch 33/40
# 69/69 - 3s - loss: 563.0467 - mean_absolute_error: 10.7877 - accuracy: 0.6544
# Epoch 34/40
# 69/69 - 3s - loss: 515.9171 - mean_absolute_error: 10.3599 - accuracy: 0.6577
# Epoch 35/40
# 69/69 - 2s - loss: 495.9330 - mean_absolute_error: 10.0823 - accuracy: 0.6650
# Epoch 36/40
# 69/69 - 2s - loss: 461.6473 - mean_absolute_error: 9.7077 - accuracy: 0.6685
# Epoch 37/40
# 69/69 - 2s - loss: 432.2116 - mean_absolute_error: 9.4872 - accuracy: 0.6901
# Epoch 38/40
# 69/69 - 3s - loss: 397.8053 - mean_absolute_error: 9.0793 - accuracy: 0.6968
# Epoch 39/40
# 69/69 - 2s - loss: 366.9057 - mean_absolute_error: 8.7379 - accuracy: 0.6968
# Epoch 40/40
# 69/69 - 3s - loss: 341.4576 - mean_absolute_error: 8.4883 - accuracy: 0.6842

# %%
# predict and compute error
predicted_trend = np.array([])
for i in range(len(test_X_trend)):
    x_input = test_X_trend[i].reshape((1, n_steps_in, n_features_trend))
    yhat = model_trend.predict(x_input, verbose=0)
    #print(yhat[0])
    predicted_trend = np.append(predicted_trend, yhat[0])  
    
    
predicted_residual = np.array([])
for i in range(len(test_X_residual)):
    x_input = test_X_residual[i].reshape((1, n_steps_in, n_features_residual))
    yhat = model_residual.predict(x_input, verbose=0)
    #print(yhat[0])
    predicted_residual = np.append(predicted_residual, yhat[0]) 

# predict and compute error
predicted_seasonal = np.array([])
for i in range(len(test_X_seasonal)):
    x_input = test_X_seasonal[i].reshape((1, n_steps_in, n_features_seasonal))
    yhat = model_seasonal.predict(x_input, verbose=0)
    #print(yhat[0])
    predicted_seasonal = np.append(predicted_seasonal, yhat[0])

# %%
predicted_final = predicted_trend + predicted_seasonal + predicted_residual
len(predicted_final)

# %%
num_data = []
## prepare dataset
for i, k in agg_by_cell:
    cell_i = agg_by_cell.get_group(i)
    cell_i = cell_i.iloc[::4, :]
    # define input sequence
    series_i = cell_i['nr_people'].values
    series_i = series_i.reshape((len(series_i), 1))
    num_data.append(series_i)

# %%
final_data = hstack((num_data))
final_data.shape
# Out:
# (2952, 221)

# %%
X, y = split_sequences(final_data, n_steps_in, n_steps_out)

# %%
n_output = y.shape[1] * y.shape[2]
y = y.reshape((y.shape[0], n_output))

# the dataset knows the number of features, e.g. 2
n_features = X.shape[2]

# %%
train_X, test_X = X[:split_train_test], X[split_train_test:]
train_y, test_y = y[:split_train_test], y[split_train_test:]
print(len(train_X), len(train_y), len(test_X), len(test_y))
# Out:
# 2187 2187 730 730

# %%
test_y.shape[0]
# Out:
# 730

# %%
test_y.shape[1]
# Out:
# 2652

# %%
len(test_y[0])
# Out:
# 2652

# %%
test_y[0]
# Out:
# array([ 37.,  38.,  39., ...,  18., 100.,  34.])

# %%
predicted_final.shape
# Out:
# (1935960,)

# %%
new_predicted = predicted_final.reshape(730, 2652)
new_predicted
# Out:
# array([[ 3.45509753e+01,  3.15501821e+01,  3.05198326e+01, ...,
#          2.33856684e+01,  1.04370637e+02,  4.98957725e+01],
#        [ 3.49038715e+01,  2.80778083e+01,  2.97762982e+01, ...,
#          2.21567841e+01,  1.04746189e+02,  5.00594468e+01],
#        [ 3.19097170e+01,  2.78645055e+01,  2.69769039e+01, ...,
#          2.30657957e+01,  1.03524503e+02,  4.96041645e+01],
#        ...,
#        [ 3.38601976e+01,  3.13389127e+01, -4.15749981e+00, ...,
#         -9.42551932e+01,  1.74882117e+02,  1.17507666e+02],
#        [ 3.80551047e+01,  3.65541131e+01,  1.06356606e-01, ...,
#         -9.35665391e+01,  1.76445409e+02,  1.21912618e+02],
#        [ 4.16522898e+01,  3.98470581e+01,  4.73873709e+00, ...,
#         -9.37847944e+01,  1.78402154e+02,  1.22267698e+02]])

# %%
diff2 = np.mean( abs((new_predicted - test_y)/test_y))*100

# %%
diff3 = abs(new_predicted - test_y)
diff3
# Out:
# array([[  2.44902473,   6.4498179 ,   8.4801674 , ...,   5.38566842,
#           4.370637  ,  15.89577254],
#        [  1.90387154,   5.92219174,   5.22370183, ...,   4.15678411,
#           2.74618917,  16.05944678],
#        [  1.90971703,   5.13549448,   8.0230961 , ...,   5.06579574,
#           0.47549743,  14.60416451],
#        ...,
#        [  2.86019761,   5.66108728,  43.15749981, ..., 110.25519316,
#          81.88211709,  86.5076662 ],
#        [  7.05510468,   1.44588686,  40.89364339, ..., 108.56653913,
#          82.44540888,  89.91261842],
#        [  9.65228982,   0.15294195,  39.26126291, ..., 108.78479442,
#          84.40215391,  90.26769766]])

# %%
diff3.shape
# Out:
# (730, 2652)

# %%
plt.figure(figsize = (20,20))
plt.boxplot(diff3, vert = False)
plt.show()

# %%
exp_y = test_y.reshape((test_y.shape[0] * test_y.shape[1])) 
len(exp_y)
# Out:
# 1935960

# %%
difference = abs(predicted_final - exp_y)
print('Mean Absolute Error = ', np.mean(difference))
plt.figure(figsize = (14,2))
plt.boxplot(difference, vert = False)
plt.show()
# Out:
# Mean Absolute Error =  33.985380467544616
